# %%
import pandas as pd
csv_stops = pd.read_csv("stops.txt", sep=',', dtype = 'unicode')
csv_stops.head()
# Out:
#   stop_id                 stop_name stop_desc   stop_lat  stop_lon
# 0    0001      CARICAMENTO/ACQUARIO      0001  44.410671  8.928418
# 1    0003  GRAMSCI 1/METRO' DARSENA      0003  44.413368  8.926332
# 2    0004         GRAMSCI 2/STATUTO      0004  44.414719  8.924177
# 3    0005        GRAMSCI 3/COMMENDA      0005  44.415524  8.922028
# 4    0006     MARITTIMA/PRINCIPE FS      0006  44.415497  8.919490

# %%
csv_stops2 = csv_stops[['stop_id','stop_name','stop_lat','stop_lon']]
#csv_stops2.sort_values(["vehicle_id","stop_id","stop_sequence"], ascending = True)
csv_stops2
# Out:
#      stop_id                 stop_name   stop_lat  stop_lon
# 0       0001      CARICAMENTO/ACQUARIO  44.410671  8.928418
# 1       0003  GRAMSCI 1/METRO' DARSENA  44.413368  8.926332
# 2       0004         GRAMSCI 2/STATUTO  44.414719  8.924177
# 3       0005        GRAMSCI 3/COMMENDA  44.415524  8.922028
# 4       0006     MARITTIMA/PRINCIPE FS  44.415497  8.919490
# ...      ...                       ...        ...       ...
# 3027    MM06          DE FERRARI/METRO  44.407700  8.934238
# 3028    MM07         S. AGOSTINO/METRO  44.404243  8.931859
# 3029    MM08            BRIGNOLE/METRO  44.406506  8.946647
# 3030    NV41         PORTO ANTICO/NAVE  44.409206  8.927400
# 3031    NV42                PEGLI/NAVE  44.424118  8.819676
#
# [3032 rows x 4 columns]

# %%
data=pd.read_csv("April2022_OpenDataGenova.csv", sep=';', dtype = 'unicode')
data
# Out:
#                                vehicle_id         arrival_time departure_time  \
# 0        9408851-I21224-InvFer-Semaine-16  2022-04-01 06:00:00       06:00:00
# 1        9408851-I21224-InvFer-Semaine-16  2022-04-01 06:01:00       06:01:00
# 2        9408851-I21224-InvFer-Semaine-16  2022-04-01 06:02:00       06:02:00
# 3        9408851-I21224-InvFer-Semaine-16  2022-04-01 06:03:00       06:03:00
# 4        9408851-I21224-InvFer-Semaine-16  2022-04-01 06:04:00       06:04:00
# ...                                   ...                  ...            ...
# 5995454  9303944-MM2022-InvFer-Semaine-00  2022-04-29 05:08:22       05:08:22
# 5995455  9303944-MM2022-InvFer-Semaine-00  2022-04-29 05:10:00       05:10:00
# 5995456  9303944-MM2022-InvFer-Semaine-00  2022-04-29 05:11:00       05:11:00
# 5995457  9303944-MM2022-InvFer-Semaine-00  2022-04-29 05:16:00       05:16:00
# 5995458                                                   NaN            NaN
#
# ...

# %%
csv_stops3 = data.merge(csv_stops2, on=['stop_id',"stop_name"])
#csv_stops3 = csv_stops3.sort_values(by=['vehicle_id','arrival_time','departure_time','stop_sequence','stopinfo_started'], ascending=True)
csv_stops3
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 csv_stops3 = data.merge(csv_stops2, on=['stop_id',"stop_name"])
#       2 #csv_stops3 = csv_stops3.sort_values(by=['vehicle_id','arrival_time','departure_time','stop_sequence','stopinfo_started'], ascending=True)
#       3 csv_stops3
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10487, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10468 @Substitution("")
#   10469 @Appender(_merge_doc, indents=2)
#   10470 def merge(
#    (...)
#   10483     validate: MergeValidate | None = None,
#   10484 ) -> DataFrame:
#   10485     from pandas.core.reshape.merge import merge
# > 10487     return merge(
#   10488         self,
#   10489         right,
# ...

# %%
#csv_stops3 = csv_stops3.sort_values(by=['vehicle_id','stop_sequence','arrival_time'], ascending=True)
#csv_stops3

# %%
csv_stops3.to_csv(r'April2022_OpenDataGenova_coordinates.csv', index = False, sep=';')

# %% [markdown]
# ## Rendo il dataset restituito da SUMO uguale al dataset di Hitachi

# %%
import pandas as pd
import numpy as np
data=pd.read_csv("dataset_sintetico_rip2.csv", sep=';', dtype = 'unicode')

#AGGIUNGO COLONNNE AL DATASET
#data['year'] = "2022"
#data['month']='2'
#data['dayofweek']='2'

#AGGIUNGO IL GIORNO AGLI ORARI
data['arrival_time']=pd.to_datetime( '25/04/2022' + data['arrival_time']  ,format='%d/%m/%Y%H:%M:%S')
data['stopinfo_started']=pd.to_datetime( '25/04/2022' + data['stopinfo_started']  ,format='%d/%m/%Y%H:%M:%S')

#CANCELLO LE COLONNE DEL DATASET CHE NON CI INTERESSANO
#data = data.drop('departure_time',axis=1)
#data = data.drop('stop_name',axis=1)
#data = data.drop('busStop_id',axis=1)
#data = data.drop('stopinfo_delay',axis=1)
#data = data.drop('stopinfo_ended',axis=1)
#data = data.drop('stopinfo_loadedPersons',axis=1)
#data = data.drop('stopinfo_type',axis=1)
#data = data.drop('stopinfo_unloadedPersons',axis=1)
#data = data.drop('trip_headsign',axis=1)
#data = data.drop('block_id',axis=1)

#RINOMINO LE COLONNE
#data.rename(columns = {'vehicle_id':'trip_id'}, inplace = True)
data.rename(columns = {'busStop_id':'stop_id_SUMO'}, inplace = True)
#data.rename(columns = {'arrival_time':'sch_arr_time'}, inplace = True)
#data.rename(columns = {'stopinfo_started':'actual_arr_time'}, inplace = True)
data
# Out:
#                               vehicle_id        arrival_time departure_time  \
# 0       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:00:00       06:00:00
# 1       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:01:00       06:01:00
# 2       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:02:00       06:02:00
# 3       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:03:00       06:03:00
# 4       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:04:00       06:04:00
# ...                                  ...                 ...            ...
# 312805  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:07:00       05:07:00
# 312806  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:08:22       05:08:22
# 312807  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:10:00       05:10:00
# 312808  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:11:00       05:11:00
# 312809  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:16:00       05:16:00
#
# ...

# %%
data['arrival_time']=pd.to_datetime(data['arrival_time'] ,format='%d/%m/%Y %H:%M:%S')
data['stopinfo_started']=pd.to_datetime(data['stopinfo_started'], format='%d/%m/%Y %H:%M:%S')
data
# Out:
#                               vehicle_id        arrival_time departure_time  \
# 0       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:00:00       06:00:00
# 1       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:01:00       06:01:00
# 2       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:02:00       06:02:00
# 3       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:03:00       06:03:00
# 4       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:04:00       06:04:00
# ...                                  ...                 ...            ...
# 312805  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:07:00       05:07:00
# 312806  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:08:22       05:08:22
# 312807  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:10:00       05:10:00
# 312808  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:11:00       05:11:00
# 312809  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:16:00       05:16:00
#
# ...

# %%
import pandas as pd
import numpy as np
data=pd.read_csv("1_11_febbraio.csv", sep=';', dtype = 'unicode')

#AGGIUNGO COLONNNE AL DATASET
#data['year'] = "2022"
#data['month']='2'
#data['dayofweek']='2'

#AGGIUNGO IL GIORNO AGLI ORARI
#data['arrival_time']=pd.to_datetime(data['arrival_time'] ,format='%d/%m/%Y %H:%M:%S')
#data['stopinfo_started']=pd.to_datetime(data['stopinfo_started'], format='%d/%m/%Y %H:%M:%S')

#CANCELLO LE COLONNE DEL DATASET CHE NON CI INTERESSANO
#data = data.drop('departure_time',axis=1)
#data = data.drop('stop_name',axis=1)
#data = data.drop('busStop_id',axis=1)
#data = data.drop('stopinfo_delay',axis=1)
#data = data.drop('stopinfo_ended',axis=1)
#data = data.drop('stopinfo_loadedPersons',axis=1)
#data = data.drop('stopinfo_type',axis=1)
#data = data.drop('stopinfo_unloadedPersons',axis=1)
#data = data.drop('trip_headsign',axis=1)
#data = data.drop('block_id',axis=1)

#RINOMINO LE COLONNE
#data.rename(columns = {'vehicle_id':'trip_id'}, inplace = True)
#data.rename(columns = {'busStop_id':'stop_id_SUMO'}, inplace = True)
#data.rename(columns = {'arrival_time':'sch_arr_time'}, inplace = True)
#data.rename(columns = {'stopinfo_started':'actual_arr_time'}, inplace = True)
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 data=pd.read_csv("1_11_febbraio.csv", sep=';', dtype = 'unicode')
#       5 #AGGIUNGO COLONNNE AL DATASET
#       6 #data['year'] = "2022"
#       7 #data['month']='2'
#    (...)
#      29 #data.rename(columns = {'arrival_time':'sch_arr_time'}, inplace = True)
#      30 #data.rename(columns = {'stopinfo_started':'actual_arr_time'}, inplace = True)
#      31 data
#
# ...

# %%
data['sumo_delay'] = (data['stopinfo_started'] - data['arrival_time']).dt.total_seconds()
data
# Out:
#                               vehicle_id        arrival_time departure_time  \
# 0       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:00:00       06:00:00
# 1       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:01:00       06:01:00
# 2       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:02:00       06:02:00
# 3       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:03:00       06:03:00
# 4       9408851-I21224-InvFer-Semaine-16 2022-04-25 06:04:00       06:04:00
# ...                                  ...                 ...            ...
# 312805  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:07:00       05:07:00
# 312806  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:08:22       05:08:22
# 312807  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:10:00       05:10:00
# 312808  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:11:00       05:11:00
# 312809  9303944-MM2022-InvFer-Semaine-00 2022-04-25 05:16:00       05:16:00
#
# ...

# %%
data.to_csv(r'Dataset_definitivo_rip2.csv', index = False, sep=';')
